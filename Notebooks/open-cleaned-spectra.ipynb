# %%
import numpy as np
from astropy.io import fits
from astropy.io import ascii
from scipy.signal import medfilt
from scipy.interpolate import interp1d
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "../Cleaned-spectra/"
namefile = "s27s07_new_apOIII_cleaned.txt"

# %%
data = ascii.read(os.path.join(path, namefile), 
                             format='basic', 
                             delimiter=' ', 
                             data_start=2,  # Saltar las primeras 2 líneas
                             names=['wavelength', 'flux'])

# %%
plt.figure(figsize=(12, 6))
    
# Crear el gráfico
plt.plot(data["wavelength"], data["flux"], 'b-', linewidth=0.8)
plt.xlabel('Wavelength (nm)', fontsize=14)
plt.ylabel('Flux (Wm^-2nm^-1)', fontsize=14)

# Añadir grid para mejor visualización
plt.grid(True, alpha=0.3)
        
# Formatear los ejes
plt.tick_params(axis='both', which='major', labelsize=12)
    
    
plt.show()

# %% [markdown]
# # Other spectra

# %%
namefile1 = "n02n27_1D_aberturaOIII_test_cleaned.txt"
data1 = ascii.read(os.path.join(path, namefile1), 
                             format='basic', 
                             delimiter=' ', 
                             data_start=2,  # Saltar las primeras 2 líneas
                             names=['wavelength', 'flux'])

# %%
plt.figure(figsize=(12, 6))
    
# Crear el gráfico
plt.plot(data1["wavelength"], data1["flux"], 'b-', linewidth=0.8)
plt.xlabel('Wavelength (nm)', fontsize=14)
plt.ylabel('Flux (Wm^-2nm^-1)', fontsize=14)

# Añadir grid para mejor visualización
plt.grid(True, alpha=0.3)
        
# Formatear los ejes
plt.tick_params(axis='both', which='major', labelsize=12)
    
    
plt.show()
